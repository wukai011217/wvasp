# %% [markdown]
# # Crystaltoolkit Relaxation Viewer
#
# This notebook shows how to visualize a CHGNet relaxation trajectory in a Plotly Dash app using Crystal Toolkit.

# %% [markdown]
# Running the last cell in this notebook should spin up a `dash` app that looks like this:
#
# ![Crystaltoolkit Relaxation Viewer Screenshot](https://user-images.githubusercontent.com/30958850/230510639-2e659c9b-3a99-438b-9668-628299171602.png)

# %%
try:
    import chgnet  # noqa: F401
except ImportError:
    # install CHGNet with extra dependencies to run the dash app in this notebook
    # https://github.com/materialsproject/crystaltoolkit
    # (only needed on Google Colab or if you didn't install these packages yet)
    # !git clone --depth 1 https://github.com/CederGroupHub/chgnet
    # !pip install './chgnet[examples]'
# Out:
# Cloning into 'chgnet'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 103 (delta 1), reused 38 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 9.84 MiB | 28.53 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Processing ./chgnet
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ase>=3.23.0 (from chgnet==0.4.0)
#   Downloading ase-3.26.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cython>=3 in /usr/local/lib/python3.12/dist-packages (from chgnet==0.4.0) (3.0.12)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from chgnet==0.4.0) (2.0.2)
# Collecting nvidia-ml-py3>=7.352.0 (from chgnet==0.4.0)
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pymatgen>=2024.9.10 (from chgnet==0.4.0)
#   Downloading pymatgen-2025.6.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from chgnet==0.4.0) (2.8.0+cu126)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from chgnet==0.4.0) (4.15.0)
# Collecting crystal-toolkit>=2023.11.3 (from chgnet==0.4.0)
#   Downloading crystal_toolkit-2025.7.31-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from chgnet==0.4.0) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from ase>=3.23.0->chgnet==0.4.0) (1.16.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.12/dist-packages (from ase>=3.23.0->chgnet==0.4.0) (3.10.0)
# Collecting crystaltoolkit-extension (from crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading crystaltoolkit-extension-0.6.0.tar.gz (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 32.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dash-mp-components>=0.4.38 (from crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading dash_mp_components-0.4.47.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 104.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash>=2.11.0 (from crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading dash-3.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting flask-caching (from crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.4.6)
# Collecting mp-api (from crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading mp_api-0.45.9-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.12/dist-packages (from crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.10.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.6.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.1.1)
# Requirement already satisfied: webcolors in /usr/local/lib/python3.12/dist-packages (from crystal-toolkit>=2023.11.3->chgnet==0.4.0) (24.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->chgnet==0.4.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->chgnet==0.4.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->chgnet==0.4.0) (2025.2)
# Collecting bibtexparser>=1.4.0 (from pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (1.5.2)
# Collecting monty>=2025.1.9 (from pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (3.5)
# Requirement already satisfied: orjson<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (3.11.3)
# Collecting palettable>=3.3.3 (from pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (5.24.1)
# Requirement already satisfied: requests>=2.32 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (2.32.4)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Collecting spglib>=2.5 (from pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading spglib-2.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (1.13.3)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet==0.4.0) (4.67.1)
# Collecting uncertainties>=3.1.4 (from pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet==0.4.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from bibtexparser>=1.4.0->pymatgen>=2024.9.10->chgnet==0.4.0) (3.2.3)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.1.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (8.7.0)
# Collecting retrying (from dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet==0.4.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet==0.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet==0.4.0) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet==0.4.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet==0.4.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet==0.4.0) (11.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->pymatgen>=2024.9.10->chgnet==0.4.0) (8.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->chgnet==0.4.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet==0.4.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet==0.4.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet==0.4.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet==0.4.0) (2025.8.3)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen>=2024.9.10->chgnet==0.4.0)
#   Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->pymatgen>=2024.9.10->chgnet==0.4.0) (1.3.0)
# Collecting jupyterlab==3.*,>=3.0.0rc13 (from crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached jupyterlab-3.6.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (7.34.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (6.4.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (5.8.1)
# Collecting jupyterlab-server~=2.19 (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.14.0)
# Collecting jupyter-ydoc~=0.2.4 (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached jupyter_ydoc-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting jupyter-server-ydoc~=0.8.0 (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached jupyter_server_ydoc-0.8.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.3.2)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (6.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->chgnet==0.4.0) (3.0.2)
# Collecting cachelib>=0.9.0 (from flask-caching->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.1.1)
# Collecting maggma>=0.57.1 (from mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading maggma-0.72.0-py3-none-any.whl.metadata (11 kB)
# Collecting emmet-core>=0.84.3rc6 (from mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading emmet_core-0.84.10rc2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.12/dist-packages (from mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (7.3.0.post1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.11.7)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.4.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2025.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.6.0)
# Collecting pymatgen-io-validation>=0.1.0 (from emmet-core>=0.84.3rc6->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading pymatgen_io_validation-0.1.1-py3-none-any.whl.metadata (15 kB)
# Collecting pybtex~=0.24 (from emmet-core>=0.84.3rc6->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading pybtex-0.25.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.2.0)
# Collecting pymongo<4.11,>=4.2.0 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading pymongo-4.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting mongomock>=3.10.0 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading mongomock-4.3.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pydash>=4.1.0 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading pydash-8.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: jsonschema>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (4.25.1)
# Collecting jsonlines>=4.0.0 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aioitertools>=0.5.1 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pyzmq>=25.1.1 in /usr/local/lib/python3.12/dist-packages (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (26.2.1)
# Collecting dnspython>=1.16.0 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting sshtunnel>=0.1.5 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading sshtunnel-0.4.0-py2.py3-none-any.whl.metadata (19 kB)
# Collecting boto3>=1.20.41 (from maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading boto3-1.40.30-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->pydantic-settings->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->pydantic-settings->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.33.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash>=2.11.0->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.23.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.17.3)
# Collecting botocore<1.41.0,>=1.40.30 (from boto3>=1.20.41->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading botocore-1.40.30-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.41->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3>=1.20.41->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines>=4.0.0->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.1.1->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.1.1->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.1.1->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.27.1)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (7.4.9)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (5.7.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (4.4.0)
# Collecting jupyter-server-fileid<1,>=0.6.0 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached jupyter_server_fileid-0.9.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting ypy-websocket<0.9.0,>=0.8.2 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached ypy_websocket-0.8.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting y-py<0.7.0,>=0.6.0 (from jupyter-ydoc~=0.2.4->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached y_py-0.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Collecting sentinels (from mongomock>=3.10.0->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading sentinels-1.1.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (6.17.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.2.4)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.12/dist-packages (from pybtex~=0.24->emmet-core>=0.84.3rc6->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (6.0.2)
# Collecting latexcodec>=1.0.4 (from pybtex~=0.24->emmet-core>=0.84.3rc6->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading latexcodec-3.0.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting paramiko>=2.7.2 (from sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jedi>=0.16 (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.8.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.21.2)
# Collecting bcrypt>=3.2 (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.12/dist-packages (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (43.0.3)
# Collecting invoke>=2.0 (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading invoke-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pynacl>=1.5 (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Downloading pynacl-1.6.0-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.2.13)
# Collecting aiofiles<23,>=22.1.0 (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached aiofiles-22.1.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting aiosqlite<1,>=0.17.0 (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0)
#   Using cached aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.8.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.3->paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.17.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.22)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.2.2)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal-toolkit>=2023.11.3->chgnet==0.4.0) (2.9.0.20250822)
# Downloading ase-3.26.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 94.2 MB/s eta 0:00:00
# Downloading crystal_toolkit-2025.7.31-py3-none-any.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 78.8 MB/s eta 0:00:00
# Downloading pymatgen-2025.6.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 100.2 MB/s eta 0:00:00
# Downloading dash-3.2.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 103.1 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 4.0 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 23.6 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.15-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 10.2 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 49.6 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 4.4 MB/s eta 0:00:00
# Using cached jupyterlab-3.6.8-py3-none-any.whl (8.9 MB)
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading mp_api-0.45.9-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.6 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading emmet_core-0.84.10rc2-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.5/264.5 kB 21.1 MB/s eta 0:00:00
# Downloading maggma-0.72.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 11.2 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (754 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.1/754.1 kB 45.0 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading boto3-1.40.30-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 12.2 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 26.1 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Using cached jupyter_server_ydoc-0.8.0-py3-none-any.whl (11 kB)
# Using cached jupyter_ydoc-0.2.5-py3-none-any.whl (6.2 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading mongomock-4.3.0-py2.py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.2 MB/s eta 0:00:00
# Downloading pybtex-0.25.1-py2.py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 12.2 MB/s eta 0:00:00
# Downloading pydash-8.0.5-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.1/102.1 kB 8.4 MB/s eta 0:00:00
# Downloading pymatgen_io_validation-0.1.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 3.7 MB/s eta 0:00:00
# Downloading pymongo-4.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 69.8 MB/s eta 0:00:00
# Downloading sshtunnel-0.4.0-py2.py3-none-any.whl (24 kB)
# Downloading botocore-1.40.30-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 74.8 MB/s eta 0:00:00
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached json5-0.12.1-py3-none-any.whl (36 kB)
# Using cached jupyter_server_fileid-0.9.3-py3-none-any.whl (16 kB)
# Downloading latexcodec-3.0.1-py3-none-any.whl (18 kB)
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 kB 18.9 MB/s eta 0:00:00
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 7.7 MB/s eta 0:00:00
# Using cached y_py-0.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Using cached ypy_websocket-0.8.4-py3-none-any.whl (10 kB)
# Downloading sentinels-1.1.1-py3-none-any.whl (3.7 kB)
# Using cached aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Using cached aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 23.5 MB/s eta 0:00:00
# Downloading invoke-2.2.0-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 14.2 MB/s eta 0:00:00
# Downloading pynacl-1.6.0-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.4 MB/s eta 0:00:00
# Building wheels for collected packages: chgnet, nvidia-ml-py3, bibtexparser, dash-mp-components, crystaltoolkit-extension
#   Building wheel for chgnet (pyproject.toml) ... done
#   Created wheel for chgnet: filename=chgnet-0.4.0-cp312-cp312-linux_x86_64.whl size=9185130 sha256=83e2b01c7375569077e1e221c47304dca60cdb844fc6eb0f4c502ab9a38618d1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jceikj6p/wheels/72/1f/c6/69266954a6b1220de9bd90e650132b4c0cf69a313e180139d7
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19172 sha256=8bad69f23e126d1277200e184a626d12d2e423d2734d54bfebb689681bdb14a8
#   Stored in directory: /root/.cache/pip/wheels/6e/65/79/33dee66cba26e8204801916dfee7481bccfd22905ebb841fe5
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=8b19c1771254340464452df67b90ce678aa2c34af79cd36008f0152e60761f9f
#   Stored in directory: /root/.cache/pip/wheels/1f/7d/e9/1ff2509f13767a55df1279744adfb757f4ab94b2cbe761f56a
#   Building wheel for dash-mp-components (setup.py) ... done
#   Created wheel for dash-mp-components: filename=dash_mp_components-0.4.47-py3-none-any.whl size=6438047 sha256=fd49b5e6449110741877149ffd49e8e4d81cb94f0828b0138773fb4db7a5f0cd
#   Stored in directory: /root/.cache/pip/wheels/d8/a6/38/e541a2bf545b63c4fa75588649ac91abd8ea5fa7a4a2b1c400
#   Building wheel for crystaltoolkit-extension (pyproject.toml) ... done
#   Created wheel for crystaltoolkit-extension: filename=crystaltoolkit_extension-0.6.0-py3-none-any.whl size=5424231 sha256=9156357f656decff496f2cf3de0477af0e52920165315402f90063b9eb04ee24
#   Stored in directory: /root/.cache/pip/wheels/56/ae/39/7025038ddbd0bf793d18a9e8604138daba4267e90fc91b42a1
# Successfully built chgnet nvidia-ml-py3 bibtexparser dash-mp-components crystaltoolkit-extension
# Installing collected packages: y-py, nvidia-ml-py3, dash-mp-components, uncertainties, spglib, sentinels, ruamel.yaml.clib, retrying, pydash, palettable, latexcodec, jupyter-ydoc, jsonlines, json5, jmespath, jedi, invoke, dnspython, cachelib, bibtexparser, bcrypt, aiosqlite, aioitertools, aiofiles, ypy-websocket, ruamel.yaml, pynacl, pymongo, pybtex, mongomock, botocore, s3transfer, paramiko, monty, flask-caching, dash, ase, sshtunnel, pymatgen, boto3, pymatgen-io-validation, maggma, chgnet, emmet-core, mp-api, jupyterlab-server, jupyter-server-fileid, jupyter-server-ydoc, jupyterlab, crystaltoolkit-extension, crystal-toolkit
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 24.1.0
#     Uninstalling aiofiles-24.1.0:
#       Successfully uninstalled aiofiles-24.1.0

# %%
import numpy as np
from pymatgen.core import Structure

# %%
try:
    from chgnet import ROOT

    structure = Structure.from_file(f"{ROOT}/examples/mp-18767-LiMnO2.cif")
except Exception:
    from urllib.request import urlopen

    url = "https://github.com/CederGroupHub/chgnet/raw/-/examples/mp-18767-LiMnO2.cif"
    cif = urlopen(url).read().decode("utf-8")
    structure = Structure.from_str(cif, fmt="cif")

# %%
print(f"original: {structure.get_space_group_info()}")

# perturb all atom positions by a small amount
for site in structure:
    site.coords += np.random.normal(size=3) * 0.3

# stretch the cell by a small amount
structure.scale_lattice(structure.volume * 1.1)

print(f"perturbed: {structure.get_space_group_info()}")
# Out:
# original: ('Pmmn', 59)
# perturbed: ('P1', 1)

# %%
import pandas as pd

from chgnet.model import StructOptimizer

trajectory = StructOptimizer().relax(structure)["trajectory"]
# Out:
# CHGNet initialized with 400,438 parameters
# CHGNet will run on mps
# /Users/janosh/dev/chgnet/chgnet/model/composition_model.py:177: UserWarning: MPS: no support for int64 min/max ops, casting it to int32 (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/ReduceOps.mm:1271.)
#   composition_fea = torch.bincount(
#       Step     Time          Energy         fmax
# *Force-consistent energies used in optimization.
# FIRE:    0 17:10:46      -39.349243*      93.7997
# FIRE:    1 17:10:46      -53.316616*      10.1811
# FIRE:    2 17:10:46      -53.377773*      15.6013
# FIRE:    3 17:10:47      -54.071163*      11.7506
# FIRE:    4 17:10:47      -54.818359*       5.3271
# FIRE:    5 17:10:48      -55.177044*       7.9573
# FIRE:    6 17:10:48      -55.661133*       9.9137
# FIRE:    7 17:10:49      -56.486736*       6.3212
# FIRE:    8 17:10:49      -57.129395*       4.4612
# FIRE:    9 17:10:50      -57.536762*       6.1146
# FIRE:   10 17:10:50      -57.886269*       2.9151
# FIRE:   11 17:10:51      -57.534672*       9.1977
# FIRE:   12 17:10:52      -57.731918*       6.6787
# FIRE:   13 17:10:52      -57.953892*       3.5996
# FIRE:   14 17:10:53      -58.058907*       2.4661
# FIRE:   15 17:10:53      -58.089428*       4.2591
# FIRE:   16 17:10:53      -58.099186*       4.0957
# FIRE:   17 17:10:54      -58.117531*       3.7736
# FIRE:   18 17:10:54      -58.142269*       3.3059
# FIRE:   19 17:10:54      -58.170528*       2.7055
# FIRE:   20 17:10:55      -58.199223*       1.9944
# FIRE:   21 17:10:55      -58.225574*       1.6872
# FIRE:   22 17:10:56      -58.247837*       1.6420
# FIRE:   23 17:10:56      -58.267609*       1.5754
# FIRE:   24 17:10:57      -58.286213*       1.5527
# FIRE:   25 17:10:58      -58.307659*       1.9544
# FIRE:   26 17:10:58      -58.336651*       2.1167
# FIRE:   27 17:10:58      -58.374733*       1.7955
# FIRE:   28 17:10:59      -58.417065*       1.2746
# FIRE:   29 17:10:59      -58.454224*       1.0842
# FIRE:   30 17:11:00      -58.482494*       1.4909
# FIRE:   31 17:11:00      -58.511620*       1.7936
# FIRE:   32 17:11:00      -58.551266*       1.3864
# FIRE:   33 17:11:00      -58.593399*       0.8655
# FIRE:   34 17:11:01      -58.626717*       1.1029
# FIRE:   35 17:11:01      -58.667667*       1.1856
# FIRE:   36 17:11:02      -58.714378*       0.7611
# FIRE:   37 17:11:02      -58.751740*       1.4115
# FIRE:   38 17:11:02      -58.798595*       0.6277
# FIRE:   39 17:11:03      -58.825634*       1.6683
# FIRE:   40 17:11:04      -58.860550*       0.6463
# FIRE:   41 17:11:04      -58.879448*       1.6940
# FIRE:   42 17:11:05      -58.889172*       1.0395
# FIRE:   43 17:11:05      -58.897785*       0.5511
# FIRE:   44 17:11:06      -58.900936*       0.9203
# FIRE:   45 17:11:06      -58.902317*       0.8079
# FIRE:   46 17:11:06      -58.904602*       0.5999
# FIRE:   47 17:11:06      -58.907150*       0.4713
# FIRE:   48 17:11:07      -58.909378*       0.4035
# FIRE:   49 17:11:07      -58.911129*       0.3782
# FIRE:   50 17:11:07      -58.912685*       0.4900
# FIRE:   51 17:11:08      -58.914524*       0.5925
# FIRE:   52 17:11:08      -58.917168*       0.5787
# FIRE:   53 17:11:09      -58.920650*       0.4262
# FIRE:   54 17:11:09      -58.924351*       0.2559
# FIRE:   55 17:11:10      -58.927425*       0.2542
# FIRE:   56 17:11:10      -58.930111*       0.4618
# FIRE:   57 17:11:10      -58.933582*       0.4244
# FIRE:   58 17:11:11      -58.937565*       0.2129
# FIRE:   59 17:11:11      -58.940548*       0.3162
# FIRE:   60 17:11:11      -58.943970*       0.3788
# FIRE:   61 17:11:11      -58.948582*       0.1709
# FIRE:   62 17:11:12      -58.952435*       0.4052
# FIRE:   63 17:11:12      -58.957687*       0.1760
# FIRE:   64 17:11:13      -58.961376*       0.4583
# FIRE:   65 17:11:13      -58.965767*       0.1113
# FIRE:   66 17:11:13      -58.967800*       0.4162
# FIRE:   67 17:11:13      -58.969425*       0.5236
# FIRE:   68 17:11:14      -58.970615*       0.2232
# FIRE:   69 17:11:14      -58.970974*       0.2027
# FIRE:   70 17:11:14      -58.971069*       0.1704
# FIRE:   71 17:11:14      -58.971218*       0.1290
# FIRE:   72 17:11:14      -58.971375*       0.1228
# FIRE:   73 17:11:15      -58.971523*       0.1153
# FIRE:   74 17:11:15      -58.971649*       0.1073
# FIRE:   75 17:11:15      -58.971767*       0.1409
# FIRE:   76 17:11:15      -58.971931*       0.1412
# FIRE:   77 17:11:15      -58.972164*       0.1046
# FIRE:   78 17:11:15      -58.972416*       0.0777

# %%
e_col = "Energy (eV)"
force_col = "Force (eV/Å)"
df_traj = pd.DataFrame(trajectory.energies, columns=[e_col])
df_traj[force_col] = [
    np.linalg.norm(force, axis=1).mean()  # mean of norm of force on each atom
    for force in trajectory.forces
]
df_traj.index.name = "step"

# %%
mp_id = "mp-18767"

dft_energy = -59.09
print(f"{dft_energy=:.2f} eV (see https://materialsproject.org/materials/{mp_id})")
# Out:
# dft_energy=-59.09 eV (see https://materialsproject.org/materials/mp-18767)

# %%
import crystal_toolkit.components as ctc
import plotly.graph_objects as go
from crystal_toolkit.settings import SETTINGS
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
from pymatgen.core import Structure

app = Dash(prevent_initial_callbacks=True, assets_folder=SETTINGS.ASSETS_PATH)

step_size = max(1, len(trajectory) // 20)  # ensure slider has max 20 steps
slider = dcc.Slider(
    id="slider", min=0, max=len(trajectory) - 1, step=step_size, updatemode="drag"
)


def plot_energy_and_forces(
    df: pd.DataFrame, step: int, e_col: str, force_col: str, title: str
) -> go.Figure:
    """Plot energy and forces as a function of relaxation step."""
    fig = go.Figure()
    # energy trace = primary y-axis
    fig.add_trace(go.Scatter(x=df.index, y=df[e_col], mode="lines", name="Energy"))
    # get energy line color
    line_color = fig.data[0].line.color

    # forces trace = secondary y-axis
    fig.add_trace(
        go.Scatter(x=df.index, y=df[force_col], mode="lines", name="Forces", yaxis="y2")
    )

    fig.update_layout(
        template="plotly_white",
        title=title,
        xaxis=dict(title="Relaxation Step"),
        yaxis=dict(title=e_col),
        yaxis2=dict(title=force_col, overlaying="y", side="right"),
        legend=dict(yanchor="top", y=1, xanchor="right", x=1),
    )

    # vertical line at the specified step
    fig.add_vline(x=step, line=dict(dash="dash", width=1))

    # horizontal line for DFT final energy
    anno = dict(text="DFT final energy", yanchor="top")
    fig.add_hline(
        y=dft_energy,
        line=dict(dash="dot", width=1, color=line_color),
        annotation=anno,
    )

    return fig


def make_title(spg_symbol: str, spg_num: int) -> str:
    """Return a title for the figure."""
    href = f"https://materialsproject.org/materials/{mp_id}/"
    return f"<a {href=}>{mp_id}</a> - {spg_symbol} ({spg_num})"


title = make_title(*structure.get_space_group_info())

graph = dcc.Graph(
    id="fig",
    figure=plot_energy_and_forces(df_traj, 0, e_col, force_col, title),
    style={"maxWidth": "50%"},
)

struct_comp = ctc.StructureMoleculeComponent(id="structure", struct_or_mol=structure)

app.layout = html.Div(
    [
        html.H1(
            "Structure Relaxation Trajectory", style=dict(margin="1em", fontSize="2em")
        ),
        html.P("Drag slider to see structure at different relaxation steps."),
        slider,
        html.Div([struct_comp.layout(), graph], style=dict(display="flex", gap="2em")),
    ],
    style=dict(margin="auto", textAlign="center", maxWidth="1200px", padding="2em"),
)

ctc.register_crystal_toolkit(app=app, layout=app.layout)


@app.callback(
    Output(struct_comp.id(), "data"), Output(graph, "figure"), Input(slider, "value")
)
def update_structure(step: int) -> tuple[Structure, go.Figure]:
    """Update the structure displayed in the StructureMoleculeComponent and the
    dashed vertical line in the figure when the slider is moved.
    """
    lattice = trajectory.cells[step]
    coords = trajectory.atom_positions[step]
    structure.lattice = lattice  # update structure in place for efficiency
    assert len(structure) == len(coords)
    for site, coord in zip(structure, coords, strict=True):
        site.coords = coord

    title = make_title(*structure.get_space_group_info())
    fig = plot_energy_and_forces(df_traj, step, e_col, force_col, title)

    return structure, fig


app.run(height=800, use_reloader=False)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
